# %%
# !git clone

# %%
# 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 내 구글 드라이브로 이동
#%cd "/content/drive/MyDrive"
# %cd "/content/"

# Yolov5 github 레포지토리 clone
# !git clone https://github.com/ultralytics/yolov5.git

# 필요한 모듈 설치
# !pip install -U -r yolov5/requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13673, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 13673 (delta 6), reused 0 (delta 0), pack-reused 13661
# Receiving objects: 100% (13673/13673), 12.20 MiB | 33.22 MiB/s, done.
# Resolving deltas: 100% (9548/9548), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.2 MB 25.6 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 47.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 53.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 269 kB/s
# ...
#      |████████████████████████████████| 5.8 MB 57.9 MB/s
# ...
#      |████████████████████████████████| 930 kB 61.4 MB/s
# ...
#   Attempting uninstall: requests
# ...

# %%
import torch

#파이토치 버전 확인, cuda device properties 확인
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.11.0+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !ls -l '/content/drive/My Drive/Colab Notebooks/datasets/test2.zip'
# Out:
# -rw------- 1 root root 12832619 May 23 01:23 '/content/drive/My Drive/Colab Notebooks/datasets/test2.zip'

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/datasets/test2.zip'
# Out:
# Archive:  /content/drive/My Drive/Colab Notebooks/datasets/test2.zip
#   inflating: test/images/1005423.jpg
#   inflating: test/images/1019419.jpg
#   inflating: test/images/1022249.jpg
#   inflating: test/images/1025059.jpg
#   inflating: test/images/1025389.jpg
#   inflating: test/images/1029739.jpg
#   inflating: test/images/1031174.jpg
#   inflating: test/images/1032245.jpg
#   inflating: test/images/1032465.jpg
#   inflating: test/images/1034509.jpg
#   inflating: test/images/1046372.jpg
#   inflating: test/images/1049289.jpg
#   inflating: test/images/1050575.jpg
#   inflating: test/images/1056187.jpg
#   inflating: test/images/1061727.jpg
#   inflating: test/images/1070221.jpg
#   inflating: test/images/1099676.jpg
#   inflating: test/images/1103941.jpg
#   inflating: test/images/1105908.jpg
#   inflating: test/images/1106558.jpg
#   inflating: test/images/1106948.jpg
#   inflating: test/images/1122249.jpg
#   inflating: test/images/1126550.jpg
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !ls -l
# Out:
# total 264
# -rw-r--r-- 1 root root  4964 May 24 00:19 CONTRIBUTING.md
# drwxr-xr-x 5 root root  4096 May 24 00:19 data
# -rw-r--r-- 1 root root 13296 May 24 00:19 detect.py
# -rw-r--r-- 1 root root 29723 May 24 00:19 export.py
# -rw-r--r-- 1 root root  6465 May 24 00:19 hubconf.py
# -rw-r--r-- 1 root root 35127 May 24 00:19 LICENSE
# drwxr-xr-x 3 root root  4096 May 24 00:19 models
# -rw-r--r-- 1 root root 15847 May 24 00:19 README.md
# -rwxr-xr-x 1 root root   950 May 24 00:19 requirements.txt
# -rw-r--r-- 1 root root  1731 May 24 00:19 setup.cfg
# drwxr-xr-x 4 root root  4096 May 24 00:20 test
# drwxr-xr-x 4 root root  4096 May 24 00:20 train
# -rw-r--r-- 1 root root 34939 May 24 00:19 train.py
# -rw-r--r-- 1 root root 57612 May 24 00:19 tutorial.ipynb
# drwxr-xr-x 7 root root  4096 May 24 00:19 utils
# drwxr-xr-x 4 root root  4096 May 24 00:20 valid
# -rw-r--r-- 1 root root 19420 May 24 00:19 val.py

# %%
# !pip install -U PyYAML
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python train.py --img 640 --batch 64 --epochs 1000 --data /content/yolov5/data/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name [datasets]
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/yolov5/data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=[datasets], exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-214-g541a5b7 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ## 동작 코드

# %%
# 코드입력 예측 결과 확인
# !python detect.py --weights ./runs/train/[datasets]4/weights/best.pt --img 640 --conf 0.5 --source /content/yolov5/datasets/valid/images/1218544.jpg
# Out:
# detect: weights=['./runs/train/[datasets]4/weights/best.pt'], source=/content/yolov5/datasets/valid/images/1218544.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-214-g541a5b7 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/datasets/valid/images/1218544.jpg: 640x512 2 프레피s, Done. (0.015s)
# Speed: 0.5ms pre-process, 15.1ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp11

# %%
# !python train.py --data "data/data.yaml" --epochs 100
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-211-gcee5959 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
